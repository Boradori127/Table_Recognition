# %%
from datasets import load_dataset

az_massive_train = load_dataset("AmazonScience/massive", "ko-KR", split='train')
az_massive_valid = load_dataset("AmazonScience/massive", "ko-KR", split='validation')
az_massive_test = load_dataset("AmazonScience/massive", "ko-KR", split='test')

# %%
# dataset count
print("Train Dataset : ", len(az_massive_train))
print("Valid Dataset : ", len(az_massive_valid))
print("Test Dataset  : ", len(az_massive_test))
# Out:
# Train Dataset :  11514
# Valid Dataset :  2033
# Test Dataset  :  2974

# %%
def filter_empty_slots(dataset): # ["slot_method"]["slot"] None filtering and delete unchanged_translation
    filtered_dataset = dataset.filter(
        lambda example: example['slot_method']['slot'] != [] and 'unchanged_translation' not in example['slot_method']['method']
    )
    return filtered_dataset


filtered_train = filter_empty_slots(az_massive_train)
filtered_valid = filter_empty_slots(az_massive_valid)
filtered_test = filter_empty_slots(az_massive_test)

print(f"Original train size: {len(az_massive_train)}, Filtered train size: {len(filtered_train)}")
print(f"Original valid size: {len(az_massive_valid)}, Filtered valid size: {len(filtered_valid)}")
print(f"Original test size: {len(az_massive_test)}, Filtered test size: {len(filtered_test)}")
# Out:
# Original train size: 11514, Filtered train size: 7757
# Original valid size: 2033, Filtered valid size: 1387
# Original test size: 2974, Filtered test size: 1980

# %%
filtered_train
# Out:
# Dataset({
#     features: ['id', 'locale', 'partition', 'scenario', 'intent', 'utt', 'annot_utt', 'worker_id', 'slot_method', 'judgments'],
#     num_rows: 7757
# })

# %%
intents_dict = {
    'datetime_query': '날짜_및_시간_조회',
    'iot_hue_lightchange': 'IoT_조명_변경',
    'transport_ticket': '교통_티켓',
    'takeaway_query': '테이크아웃_문의',
    'qa_stock': '주식_문의',
    'general_greet': '일반_인사',
    'recommendation_events': '이벤트_추천',
    'music_dislikeness': '음악_비호감',
    'iot_wemo_off': 'IoT_Wemo_끄기',
    'cooking_recipe': '요리_레시피',
    'qa_currency': '환율_문의',
    'transport_traffic': '교통_혼잡도',
    'general_quirky': '일반_독특함',
    'weather_query': '날씨_문의',
    'audio_volume_up': '오디오_볼륨_올리기',
    'email_addcontact': '이메일_연락처_추가',
    'takeaway_order': '테이크아웃_주문',
    'email_querycontact': '이메일_연락처_조회',
    'iot_hue_lightup': 'IoT_조명_밝게_하기',
    'recommendation_locations': '장소_추천',
    'play_audiobook': '오디오북_재생',
    'lists_createoradd': '목록_생성_또는_추가',
    'news_query': '뉴스_문의',
    'alarm_query': '알람_조회',
    'iot_wemo_on': 'IoT_Wemo_켜기',
    'general_joke': '일반_농담',
    'qa_definition': '정의_문의',
    'social_query': '소셜_문의',
    'music_settings': '음악_설정',
    'audio_volume_other': '오디오_볼륨_기타_설정',
    'calendar_remove': '캘린더_삭제',
    'iot_hue_lightdim': 'IoT_조명_어둡게_하기',
    'calendar_query': '캘린더_조회',
    'email_sendemail': '이메일_보내기',
    'iot_cleaning': 'IoT_청소',
    'audio_volume_down': '오디오_볼륨_낮추기',
    'play_radio': '라디오_재생',
    'cooking_query': '요리_문의',
    'datetime_convert': '날짜_및_시간_변환',
    'qa_maths': '수학_문의',
    'iot_hue_lightoff': 'IoT_조명_끄기',
    'iot_hue_lighton': 'IoT_조명_켜기',
    'transport_query': '교통_조회',
    'music_likeness': '음악_호감',
    'email_query': '이메일_문의',
    'play_music': '음악_재생',
    'audio_volume_mute': '오디오_볼륨_음소거',
    'social_post': '소셜_게시',
    'alarm_set': '알람_설정',
    'qa_factoid': '사실_문의',
    'calendar_set': '캘린더_설정',
    'play_game': '게임_재생',
    'alarm_remove': '알람_삭제',
    'lists_remove': '목록_제거',
    'transport_taxi': '택시',
    'recommendation_movies': '영화_추천',
    'iot_coffee': 'IoT_커피',
    'music_query': '음악_문의',
    'play_podcasts': '팟캐스트_재생',
    'lists_query': '목록_조회'
}

_INTENTS_KO = [value for key, value in intents_dict.items()]

# ## intent dict 형태로 변환

# def intent_dict_save(file_path, intents_dict):
#     intents_dict_modified = {k: v.replace(" ", "_") for k, v in intents_dict.items()}
#     dict_str = "\n".join([f"{key}: {value}" for key, value in intents_dict_modified.items()])
#     with open(file_path, "w", encoding="utf-8") as file:
#         file.write(dict_str)
#     return intents_dict_modified
        
# file_path = '/home/oks/oks/people/mj/[2024]OKS/DATA_eda/intent_dic'
# intent_dict_update = intent_dict_save(file_path, intents_dict)

# %%
slot_dict = {
    'sport_type': '운동_유형',
    'food_type': '음식_유형',
    'place_name': '장소_이름',
    'device_type': '장치_유형',
    'music_album': '음악_앨범',
    'currency_name': '화폐_이름',
    'definition_word': '정의_단어',
    'time': '시간',
    'transport_type': '교통_유형',
    'person': '사람',
    'business_name': '비즈니스_이름',
    'general_frequency': '일반_빈도',
    'player_setting': '플레이어_설정',
    'radio_name': '라디오_이름',
    'personal_info': '개인_정보',
    'ingredient': '재료',
    'event_name': '이벤트_이름',
    'playlist_name': '재생목록_이름',
    'song_name': '노래_이름',
    'movie_type': '영화_유형',
    'movie_name': '영화_이름',
    'coffee_type': '커피_유형',
    'drink_type': '음료_유형',
    'transport_descriptor': '교통_설명자',
    'audiobook_name': '오디오북_이름',
    'house_place': '집_장소',
    'transport_agency': '교통_기관',
    'date': '날짜',
    'music_genre': '음악_장르',
    'business_type': '비즈니스_유형',
    'game_type': '게임_유형',
    'game_name': '게임_이름',
    'podcast_descriptor': '팟캐스트_설명',
    'cooking_type': '요리_유형',
    'email_folder': '이메일_폴더',
    'meal_type': '식사_유형',
    'podcast_name': '팟캐스트_이름',
    'email_address': '이메일_주소',
    'app_name': '앱_이름',
    'order_type': '주문_유형',
    'transport_name': '교통_이름',
    'color_type': '색상_유형',
    'weather_descriptor': '날씨_설명',
    'change_amount': '변경_금액',
    'time_zone': '시간대',
    'joke_type': '농담_유형',
    'news_topic': '뉴스_주제',
    'media_type': '미디어_유형',
    'timeofday': '시간대',
    'alarm_type': '알람_유형',
    'list_name': '목록_이름',
    'music_descriptor': '음악_설명',
    'artist_name': '아티스트_이름',
    'audiobook_author': '오디오북_저자',
    'relation': '관계'
}

# %%
import re

pattern = r'\[(.*?)\]'

# _INTENTS = ['datetime_query', 'iot_hue_lightchange', 'transport_ticket', 'takeaway_query', 'qa_stock',
#             'general_greet', 'recommendation_events', 'music_dislikeness', 'iot_wemo_off', 'cooking_recipe',
#             'qa_currency', 'transport_traffic', 'general_quirky', 'weather_query', 'audio_volume_up',
#             'email_addcontact', 'takeaway_order', 'email_querycontact', 'iot_hue_lightup',
#             'recommendation_locations', 'play_audiobook', 'lists_createoradd', 'news_query',
#             'alarm_query', 'iot_wemo_on', 'general_joke', 'qa_definition', 'social_query',
#             'music_settings', 'audio_volume_other', 'calendar_remove', 'iot_hue_lightdim',
#             'calendar_query', 'email_sendemail', 'iot_cleaning', 'audio_volume_down',
#             'play_radio', 'cooking_query', 'datetime_convert', 'qa_maths', 'iot_hue_lightoff',
#             'iot_hue_lighton', 'transport_query', 'music_likeness', 'email_query', 'play_music',
#             'audio_volume_mute', 'social_post', 'alarm_set', 'qa_factoid', 'calendar_set',
#             'play_game', 'alarm_remove', 'lists_remove', 'transport_taxi', 'recommendation_movies',
#             'iot_coffee', 'music_query', 'play_podcasts', 'lists_query']


def parse_text(text): ## > '[date : 금요일]', '[time : 오전 아홉 시]', '에', '깨워줘'
    pattern = re.compile(r'\[.*?\]|\S+')
    matches = pattern.findall(text)
    return matches

def matching_intent(idx_intent, _INTENTS_KO):
    id_of_intent = idx_intent
    intent_str = _INTENTS_KO[id_of_intent]
    return intent_str

def slot_extract(annot_utt, slot_dict):
    result = []
    slot_entity_name = []
    slot_entity_element = []
    
    parsed_list = parse_text(annot_utt)
    
    for word in parsed_list:
        if ":" in word:
            word = word[1:-1]
            entity_name = word.split(':')[0].strip()
            entity_name_ko = slot_dict[entity_name]
            entity_element = word.split(':')[1].strip().split() # ['오후', '아홉시']
            for i in entity_element:    
                if i == entity_element[0]:
                    slot_entity_name.append("B_" + entity_name_ko)
                    slot_entity_element.append(i)
                else:
                    slot_entity_name.append("I_" + entity_name_ko)
                    slot_entity_element.append(i)
        else:
            entity_name = "O"
            entity_element = word
            slot_entity_name.append(entity_name)
            slot_entity_element.append(entity_element)
    
    # print(slot_entity_name)
    # print(slot_entity_name)
    for name, element in zip(slot_entity_name, slot_entity_element):
        result.append({"text": element, "entity": name})
        
    output_slot = " ".join(slot_entity_name)
    return result, output_slot

# %%
# # intent : English > Korean (make dict)

# for idx in filtered_test:
#     intent_class = matching_intent(idx['intent'], _INTENTS_KO)
#     if intent_class == '이메일_문의':
#         print(idx)
        
# # ## 'id': '7353' Intent 분류 잘못된 것 같음
# # ##
# Out:
# {'id': '7353', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '다음 주 강원도 날씨 알려줘', 'annot_utt': '[time : 다음 주] [place_name : 강원도] 날씨 알려줘', 'worker_id': '38', 'slot_method': {'slot': ['time', 'place_name'], 'method': ['translation', 'localization']}, 'judgments': {'worker_id': ['16', '3', '30'], 'intent_score': [1, 1, 0], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '15809', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '시우가 아직 이메일 안 보냈나', 'annot_utt': '[person : 시우가] 아직 이메일 안 보냈나', 'worker_id': '14', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['5', '16', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '15862', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '엄마한테서 온 이메일을 확인해 줘', 'annot_utt': '[relation : 엄마한테서] 온 이메일을 확인해 줘', 'worker_id': '14', 'slot_method': {'slot': ['relation'], 'method': ['translation']}, 'judgments': {'worker_id': ['38', '23', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 3], 'spelling_score': [1, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '15890', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '아빠가 보낸 새 이메일들이 있는지 확인해', 'annot_utt': '[relation : 아빠가 보낸] 새 이메일들이 있는지 확인해', 'worker_id': '38', 'slot_method': {'slot': ['relation'], 'method': ['translation']}, 'judgments': {'worker_id': ['14', '30', '26'], 'intent_score': [1, 1, 1], 'slots_score': [0, 1, 1], 'grammar_score': [4, 4, 3], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '15963', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '수진 한테 온 어떤 새로운 이메일 나 받았어', 'annot_utt': '[person : 수진] 한테 온 어떤 새로운 이메일 나 받았어', 'worker_id': '13', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['7', '0', '11'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 3], 'spelling_score': [1, 2, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '15970', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '엄마의 마지막 이메일이 무슨 내용이었지', 'annot_utt': '[relation : 엄마의] 마지막 이메일이 무슨 내용이었지', 'worker_id': '38', 'slot_method': {'slot': ['relation'], 'method': ['translation']}, 'judgments': {'worker_id': ['30', '36', '16'], 'intent_score': [2, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 3], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16010', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '내 수신함에 새로운 메시지들이 있는지 말해줘', 'annot_utt': '내 [email_folder : 수신함에] 새로운 메시지들이 있는지 말해줘', 'worker_id': '38', 'slot_method': {'slot': ['email_folder'], 'method': ['translation']}, 'judgments': {'worker_id': ['38', '30', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 3], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16038', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '강훈이 최근에 보낸 이메일 있나', 'annot_utt': '[person : 강훈이] 최근에 보낸 이메일 있나', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['23', '14', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16061', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지난 십 분 안에 받은 이메일이 있나', 'annot_utt': '[time : 지난 십 분] 안에 받은 이메일이 있나', 'worker_id': '38', 'slot_method': {'slot': ['time'], 'method': ['translation']}, 'judgments': {'worker_id': ['23', '30', '36'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16075', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '호현에게 온 최근 이메일 보여줘', 'annot_utt': '[person : 호현에게] 온 최근 이메일 보여줘', 'worker_id': '9', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['14', '30', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16089', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지난 십 분 내에 새로운 이메일을 받은 게 있니', 'annot_utt': '[time : 지난 십 분] 내에 새로운 이메일을 받은 게 있니', 'worker_id': '38', 'slot_method': {'slot': ['time'], 'method': ['translation']}, 'judgments': {'worker_id': ['30', '16', '38'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16096', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '진희 가 새 이메일 보냈어', 'annot_utt': '[person : 진희] 가 새 이메일 보냈어', 'worker_id': '23', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '36', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [3, 3, 4], 'spelling_score': [1, 1, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16098', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '수진 한테 온 읽지 않은 이메일 확인해', 'annot_utt': '[person : 수진] 한테 온 읽지 않은 이메일 확인해', 'worker_id': '28', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['23', '38', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 3], 'spelling_score': [2, 1, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16151', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '오늘 메일에서 미팅 일정 확인해줘', 'annot_utt': '[date : 오늘] 메일에서 [event_name : 미팅] 일정 확인해줘', 'worker_id': '9', 'slot_method': {'slot': ['event_name', 'date'], 'method': ['translation', 'translation']}, 'judgments': {'worker_id': ['23', '30', '38'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16163', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '어제 누가 나한테 메일 보낸거야', 'annot_utt': '[date : 어제] 누가 나한테 메일 보낸거야', 'worker_id': '25', 'slot_method': {'slot': ['date'], 'method': ['translation']}, 'judgments': {'worker_id': ['2', '30', '36'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16165', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지윤이가 답장했나', 'annot_utt': '[person : 지윤이가] 답장했나', 'worker_id': '25', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['2', '36', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16168', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지난 십오 분 동안 온 이메일 있나', 'annot_utt': '지난 [time : 십오 분] 동안 온 이메일 있나', 'worker_id': '38', 'slot_method': {'slot': ['time'], 'method': ['translation']}, 'judgments': {'worker_id': ['14', '23', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16170', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '받은 편지함을 열어서 읽지 않은 메일들 확인해봐', 'annot_utt': '[email_folder : 받은 편지함을] 열어서 읽지 않은 메일들 확인해봐', 'worker_id': '38', 'slot_method': {'slot': ['email_folder'], 'method': ['translation']}, 'judgments': {'worker_id': ['36', '30', '38'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16178', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '오늘 진영이한테서 온 메일이 있나', 'annot_utt': '[date : 오늘] [person : 진영이한테서] 온 메일이 있나', 'worker_id': '14', 'slot_method': {'slot': ['person', 'date'], 'method': ['localization', 'translation']}, 'judgments': {'worker_id': ['14', '23', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16263', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '봉수한테서 새 이메일 받은 거 있니', 'annot_utt': '[person : 봉수한테서] 새 이메일 받은 거 있니', 'worker_id': '30', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '38', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16271', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '내 받은편지함 새로고침하고 새 이메일에 대해 알려줘', 'annot_utt': '내 [email_folder : 받은편지함] 새로고침하고 새 이메일에 대해 알려줘', 'worker_id': '9', 'slot_method': {'slot': ['email_folder'], 'method': ['translation']}, 'judgments': {'worker_id': ['14', '30', '23'], 'intent_score': [1, 1, 1], 'slots_score': [0, 1, 1], 'grammar_score': [4, 3, 4], 'spelling_score': [1, 1, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16317', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '유진이 보낸 새 이메일이 있나', 'annot_utt': '[person : 유진이] 보낸 새 이메일이 있나', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['36', '30', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16353', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '선우에게 온 이메일들 체크해줘', 'annot_utt': '[person : 선우에게] 온 이메일들 체크해줘', 'worker_id': '9', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '36', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16354', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '내 회사에서 온 이메일들 확인해줘', 'annot_utt': '내 [relation : 회사에서] 온 이메일들 확인해줘', 'worker_id': '9', 'slot_method': {'slot': ['relation'], 'method': ['translation']}, 'judgments': {'worker_id': ['30', '16', '23'], 'intent_score': [1, 1, 1], 'slots_score': [0, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16356', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '총기관리 제목으로 재준에게 이메일 보냈나', 'annot_utt': '총기관리 제목으로 [person : 재준에게] 이메일 보냈나', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '2', '36'], 'intent_score': [0, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [1, 2, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16357', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '선정 이가 탄약에 관해 나한테 메일 보냈어', 'annot_utt': '[person : 선정] 이가 탄약에 관해 나한테 메일 보냈어', 'worker_id': '24', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['38', '23', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [1, 2, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16361', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지난 한 시간 동안 새 이메일을 받은 게 있나', 'annot_utt': '[time : 지난 한 시간] 동안 새 이메일을 받은 게 있나', 'worker_id': '38', 'slot_method': {'slot': ['time'], 'method': ['translation']}, 'judgments': {'worker_id': ['30', '36', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16413', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '내 상사가 보낸 모든 이메일들 보여줘', 'annot_utt': '내 [relation : 상사가] 보낸 모든 이메일들 보여줘', 'worker_id': '38', 'slot_method': {'slot': ['relation'], 'method': ['translation']}, 'judgments': {'worker_id': ['36', '30', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16427', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '오늘 새로운 이메일 몇 개 받았어', 'annot_utt': '[date : 오늘] 새로운 이메일 몇 개 받았어', 'worker_id': '28', 'slot_method': {'slot': ['date'], 'method': ['translation']}, 'judgments': {'worker_id': ['38', '30', '14'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16471', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '진혁에게서 온 이메일 확인해봐', 'annot_utt': '[person : 진혁에게서] 온 이메일 확인해봐', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '23', '14'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16603', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '삼십 분 전에 엄마로부터 온 이메일의 내용이 뭐지', 'annot_utt': '[time : 삼십 분] 전에 [relation : 엄마로부터] 온 이메일의 내용이 뭐지', 'worker_id': '38', 'slot_method': {'slot': ['time', 'relation'], 'method': ['translation', 'translation']}, 'judgments': {'worker_id': ['14', '30', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16642', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '효진이한테 온 메일 있는 지 확인해봐', 'annot_utt': '[person : 효진이한테] 온 메일 있는 지 확인해봐', 'worker_id': '25', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '2', '36'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [3, 4, 4], 'spelling_score': [1, 2, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16652', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '현우의 이메일에 첨부가 있니', 'annot_utt': '[person : 현우의] 이메일에 첨부가 있니', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['14', '30', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16662', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '동민에게서 새 이메일을 받은 게 있니', 'annot_utt': '[person : 동민에게서] 새 이메일을 받은 게 있니', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['26', '30', '36'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [2, 3, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16668', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '오늘 네 시 이후 이메일 온 거 있어', 'annot_utt': '[date : 오늘] [time : 네 시] 이후 이메일 온 거 있어', 'worker_id': '23', 'slot_method': {'slot': ['time', 'date'], 'method': ['translation', 'translation']}, 'judgments': {'worker_id': ['9', '30', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16669', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '민수로부터 이메일 받았니', 'annot_utt': '[person : 민수로부터] 이메일 받았니', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['14', '30', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 3], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16672', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '경식이에게 연락이 왔나', 'annot_utt': '[person : 경식이에게] 연락이 왔나', 'worker_id': '14', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['23', '38', '30'], 'intent_score': [1, 1, 2], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16677', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '오늘 받은편지함에 새 이메일들이 있나', 'annot_utt': '[date : 오늘] [email_folder : 받은편지함에] 새 이메일들이 있나', 'worker_id': '38', 'slot_method': {'slot': ['email_folder', 'date'], 'method': ['translation', 'translation']}, 'judgments': {'worker_id': ['30', '9', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [3, 4, 4], 'spelling_score': [1, 2, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16730', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '영준이에게서 새 이메일 왔어', 'annot_utt': '[person : 영준이에게서] 새 이메일 왔어', 'worker_id': '9', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['16', '30', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16733', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '네이버로 부터 최근 이메일들 보여줘', 'annot_utt': '[business_name : 네이버로] 부터 최근 이메일들 보여줘', 'worker_id': '30', 'slot_method': {'slot': ['business_name'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '14', '36'], 'intent_score': [1, 2, 1], 'slots_score': [1, 1, 1], 'grammar_score': [3, 3, 4], 'spelling_score': [1, 1, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16749', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '오늘 온 새 이메일이 있니', 'annot_utt': '[date : 오늘] 온 새 이메일이 있니', 'worker_id': '38', 'slot_method': {'slot': ['date'], 'method': ['translation']}, 'judgments': {'worker_id': ['38', '5', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16763', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지난 십 분 동안 온 이메일들이 있나', 'annot_utt': '[time : 지난 십 분] 동안 온 이메일들이 있나', 'worker_id': '38', 'slot_method': {'slot': ['time'], 'method': ['translation']}, 'judgments': {'worker_id': ['30', '14', '36'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [3, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16765', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '어제 이메일에 인터뷰 몇 시 라고 했지', 'annot_utt': '[date : 어제] 이메일에 인터뷰 몇 시 라고 했지', 'worker_id': '30', 'slot_method': {'slot': ['date'], 'method': ['translation']}, 'judgments': {'worker_id': ['23', '5', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 3], 'spelling_score': [2, 2, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16799', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '정오 이후에 이메일 받은 게 있니', 'annot_utt': '[timeofday : 정오] 이후에 이메일 받은 게 있니', 'worker_id': '38', 'slot_method': {'slot': ['timeofday'], 'method': ['translation']}, 'judgments': {'worker_id': ['23', '30', '36'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16801', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '경희가 보낸 동희 관련 어떠한 이메일 있어', 'annot_utt': '[person : 경희가] 보낸 [person : 동희] 관련 어떠한 이메일 있어', 'worker_id': '13', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['7', '0', '11'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 3], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16813', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '한경의 이메일을 받으면 소리로 알려줘', 'annot_utt': '[person : 한경의] 이메일을 받으면 소리로 알려줘', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['14', '30', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 3], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16859', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '나의 마지막 이메일에 영희 한테 내가 뭐라고 말했지', 'annot_utt': '나의 마지막 이메일에 [person : 영희] 한테 내가 뭐라고 말했지', 'worker_id': '13', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['7', '11', '0'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 4], 'spelling_score': [2, 1, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16899', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '정준호한테서 온 메일 있어', 'annot_utt': '[person : 정준호한테서] 온 메일 있어', 'worker_id': '41', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '36', '23'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16974', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '소득세부서 한테 온 모든 새로울 이메일 체크해 줘', 'annot_utt': '[business_name : 소득세부서] 한테 온 모든 새로울 이메일 체크해 줘', 'worker_id': '13', 'slot_method': {'slot': ['business_name'], 'method': ['translation']}, 'judgments': {'worker_id': ['0', '7', '11'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 0], 'grammar_score': [4, 4, 2], 'spelling_score': [2, 1, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16987', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '준석 이 새 이메일 보냈어', 'annot_utt': '[person : 준석] 이 새 이메일 보냈어', 'worker_id': '23', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['26', '30', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [3, 3, 4], 'spelling_score': [2, 1, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '16992', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '김영희가 내게 메일 보냈니', 'annot_utt': '[person : 김영희가] 내게 메일 보냈니', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '38', '9'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [3, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17075', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '오늘 네 시 이후에 받은 새 메일이 있나', 'annot_utt': '[date : 오늘] [time : 네 시 이후에] 받은 새 메일이 있나', 'worker_id': '38', 'slot_method': {'slot': ['time', 'date'], 'method': ['translation', 'translation']}, 'judgments': {'worker_id': ['38', '36', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17087', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '시연이한테서 새로 온 이메일을 열어 줘', 'annot_utt': '[person : 시연이한테서] 새로 온 이메일을 열어 줘', 'worker_id': '14', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['30', '26', '9'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 3, 3], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17098', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지난 한 시간 동안 온 이메일을 보여줘', 'annot_utt': '[time : 지난 한 시간] 동안 온 이메일을 보여줘', 'worker_id': '14', 'slot_method': {'slot': ['time'], 'method': ['translation']}, 'judgments': {'worker_id': ['30', '9', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17119', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '아마존 한테 온 어떤 메일 있나 체크해 줘', 'annot_utt': '[person : 아마존] 한테 온 어떤 메일 있나 체크해 줘', 'worker_id': '13', 'slot_method': {'slot': ['person'], 'method': ['unchanged']}, 'judgments': {'worker_id': ['0', '7', '11'], 'intent_score': [1, 1, 1], 'slots_score': [1, 0, 1], 'grammar_score': [4, 4, 3], 'spelling_score': [2, 1, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17142', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '우리가 마지막으로 학인한 후에 받은 편지함에 새로운 메일이 온 게 있나', 'annot_utt': '우리가 마지막으로 학인한 후에 [email_folder : 받은 편지함에] 새로운 메일이 온 게 있나', 'worker_id': '38', 'slot_method': {'slot': ['email_folder'], 'method': ['translation']}, 'judgments': {'worker_id': ['30', '16', '14'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [3, 4, 4], 'spelling_score': [2, 1, 1], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17156', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지영이한테서 새로 온 이메일이 있으면 확인해 줘', 'annot_utt': '[person : 지영이한테서] 새로 온 이메일이 있으면 확인해 줘', 'worker_id': '14', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['38', '23', '30'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [1, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17157', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '준호한테서 온 새 이메일이 있나', 'annot_utt': '[person : 준호한테서] 온 새 이메일이 있나', 'worker_id': '14', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['23', '30', '5'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17170', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '지화가 언제 내게 이메일 보냈는지 알려줘', 'annot_utt': '[person : 지화가] 언제 내게 이메일 보냈는지 알려줘', 'worker_id': '38', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['36', '30', '38'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}
# {'id': '17179', 'locale': 'ko-KR', 'partition': 'test', 'scenario': 7, 'intent': 44, 'utt': '주호가 보낸 이메일 있었니', 'annot_utt': '[person : 주호가] 보낸 이메일 있었니', 'worker_id': '30', 'slot_method': {'slot': ['person'], 'method': ['localization']}, 'judgments': {'worker_id': ['36', '30', '2'], 'intent_score': [1, 1, 1], 'slots_score': [1, 1, 1], 'grammar_score': [4, 4, 4], 'spelling_score': [2, 2, 2], 'language_identification': ['target', 'target', 'target']}}

# %%
def making_data_structure(idx):
    intent_class = matching_intent(idx['intent'], _INTENTS_KO)
    
    ## slot
    slot_result, output = slot_extract(idx['annot_utt'], slot_dict)
    
    return {
        idx['id']: {
            "text" : idx['utt'],
            "intent" : intent_class,
            "slot_out" : output,
            "slot_mapping" : slot_result 
        }
    }

# %%
import json 
import re

train_json = {}
valid_json = {}
test_json = {}

for idx in filtered_train:
    result = making_data_structure(idx)
    train_json.update(result)

for idx in filtered_valid:
    result = making_data_structure(idx)
    valid_json.update(result)
    
for idx in filtered_test:
    result = making_data_structure(idx)
    test_json.update(result)

# Save to JSON file
with open('train_amazon_massive.json', 'w', encoding='utf-8') as json_file:
    json.dump(train_json, json_file, ensure_ascii=False, indent=4)
    
with open('valid_amazon_massive.json', 'w', encoding='utf-8') as json_file:
    json.dump(valid_json, json_file, ensure_ascii=False, indent=4)
    
with open('test_amazon_massive.json', 'w', encoding='utf-8') as json_file:
    json.dump(test_json, json_file, ensure_ascii=False, indent=4)    

print("JSON file created successfully.")

# %%
# print(len(train_json))
# print(len(valid_json))
# print(len(test_json))
